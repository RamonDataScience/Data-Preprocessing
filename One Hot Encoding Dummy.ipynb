# %% [markdown]
# # PRE-PROCESAMIENTO DE DATOS

# %% [markdown]
# ### IMPORTAR LIBRERIAS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### IMPORTAMOS DATOS CSV

# %%
dfhr = pd.read_csv('HRDataset_v14.csv')

# %%
dfhr.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
dfhr.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
dfhr.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
# Hacemos una seleción parcial de las 36 columnas, para hacer un analisis más enfocado.

# %%
dfhr1 = dfhr[["Employee_Name","State","Position", "Sex", "DOB","MaritalDesc",
              "CitizenDesc","Department","PerformanceScore","EngagementSurvey","EmpSatisfaction"]]

# %%
dfhr1.shape
# Out:
# (311, 11)

# %%
dfhr1.describe()
# Out:
#        EngagementSurvey  EmpSatisfaction
# count        311.000000       311.000000
# mean           4.110000         3.890675
# std            0.789938         0.909241
# min            1.120000         1.000000
# 25%            3.690000         3.000000
# 50%            4.280000         4.000000
# 75%            4.700000         5.000000
# max            5.000000         5.000000

# %%
dfhr1.head()
# Out:
#               Employee_Name State                  Position Sex       DOB  \
# 0       Adinolfi, Wilson  K    MA   Production Technician I  M   07/10/83
# 1  Ait Sidi, Karthikeyan       MA                   Sr. DBA  M   05/05/75
# 2         Akinkuolie, Sarah    MA  Production Technician II   F  09/19/88
# 3              Alagbe,Trina    MA   Production Technician I   F  09/27/88
# 4          Anderson, Carol     MA   Production Technician I   F  09/08/89
#
#   MaritalDesc CitizenDesc         Department PerformanceScore  \
# 0      Single  US Citizen  Production                 Exceeds
# 1     Married  US Citizen              IT/IS      Fully Meets
# 2     Married  US Citizen  Production             Fully Meets
# 3     Married  US Citizen  Production             Fully Meets
# 4    Divorced  US Citizen  Production             Fully Meets
#
#    EngagementSurvey  EmpSatisfaction
# 0              4.60                5
# 1              4.96                3
# ...

# %%
# Creamos un Dataframe con las variables Dummy

dummy_sex = pd.get_dummies(dfhr1["Sex"], prefix = "sex")

# %%
dummy_sex.head()
# Out:
#    sex_F  sex_M
# 0      0       1
# 1      0       1
# 2      1       0
# 3      1       0
# 4      1       0

# %%
# Ahora incluimos las variables Dummy al Dataset original
# Borramos "Sex" del Dataframe original
dfhr1 = dfhr1.drop(["Sex"], axis = 1)

# %%
dfhr1.shape
# Out:
# (311, 10)

# %%
dfhr2 = pd.concat([dfhr1, dummy_sex], axis = 1)

# %%
dfhr2.shape
# Out:
# (311, 12)

# %%
dfhr2.head()
# Out:
#               Employee_Name State                  Position       DOB  \
# 0       Adinolfi, Wilson  K    MA   Production Technician I  07/10/83
# 1  Ait Sidi, Karthikeyan       MA                   Sr. DBA  05/05/75
# 2         Akinkuolie, Sarah    MA  Production Technician II  09/19/88
# 3              Alagbe,Trina    MA   Production Technician I  09/27/88
# 4          Anderson, Carol     MA   Production Technician I  09/08/89
#
#   MaritalDesc CitizenDesc         Department PerformanceScore  \
# 0      Single  US Citizen  Production                 Exceeds
# 1     Married  US Citizen              IT/IS      Fully Meets
# 2     Married  US Citizen  Production             Fully Meets
# 3     Married  US Citizen  Production             Fully Meets
# 4    Divorced  US Citizen  Production             Fully Meets
#
#    EngagementSurvey  EmpSatisfaction  sex_F  sex_M
# 0              4.60                5      0       1
# 1              4.96                3      0       1
# ...

# %%
# Ahora hacemos lo mismo que antes pero automatizandolo con funciones

# %%
def createdummies(df, varname):
    dummy = pd.get_dummies(df[varname], prefix = varname)
    df = df.drop(varname, axis = 1)
    df = pd.concat([df, dummy], axis = 1)
    return df

# %%
createdummies(dfhr2, "CitizenDesc")
# Out:
#                 Employee_Name State                  Position       DOB  \
# 0         Adinolfi, Wilson  K    MA   Production Technician I  07/10/83
# 1    Ait Sidi, Karthikeyan       MA                   Sr. DBA  05/05/75
# 2           Akinkuolie, Sarah    MA  Production Technician II  09/19/88
# 3                Alagbe,Trina    MA   Production Technician I  09/27/88
# 4            Anderson, Carol     MA   Production Technician I  09/08/89
# ..                        ...   ...                       ...       ...
# 306            Woodson, Jason    MA  Production Technician II  05/11/85
# 307        Ybarra, Catherine     MA   Production Technician I  05/04/82
# 308          Zamora, Jennifer    MA                       CIO  08/30/79
# 309               Zhou, Julia    MA              Data Analyst  02/24/79
# 310             Zima, Colleen    MA   Production Technician I  08/17/78
#
#     MaritalDesc         Department PerformanceScore  EngagementSurvey  \
# ...
